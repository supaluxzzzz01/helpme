# %% [markdown]
# Import library

# %%
import pandas as pd
import numpy as np
import math
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %% [markdown]
# Import data

# %%
df = pd.read_csv('posture.csv')

# %%
df.head()
# Out:
#    tester      time  diff_shoulder  ratio_armR  ratio_armL  diff_hip  \
# 0       1       NaN       0.006876    0.374576    0.452962  0.004783
# 1       1 -4.999956       0.006349    0.176537    0.223549  0.006989
# 2       1 -4.931930       0.005293    0.059412    0.106444  0.006060
# 3       1 -4.866806       0.004290    0.011301    0.045611  0.005444
# 4       1 -4.800642       0.003731    0.049095    0.008524  0.005096
#
#    ratio_legR  ratio_legL
# 0    1.234655    1.093391
# 1    1.203576    1.145825
# 2    1.189136    1.120530
# 3    1.184396    1.151255
# 4    1.209700    1.165597

# %%
df.dtypes
# Out:
# tester             int64
# time             float64
# diff_shoulder    float64
# ratio_armR       float64
# ratio_armL       float64
# diff_hip         float64
# ratio_legR       float64
# ratio_legL       float64
# dtype: object

# %%
df.round(decimals = 5)
# Out:
#      tester     time  diff_shoulder  ratio_armR  ratio_armL  diff_hip  \
# 0         1      NaN        0.00688     0.37458     0.45296   0.00478
# 1         1 -4.99996        0.00635     0.17654     0.22355   0.00699
# 2         1 -4.93193        0.00529     0.05941     0.10644   0.00606
# 3         1 -4.86681        0.00429     0.01130     0.04561   0.00544
# 4         1 -4.80064        0.00373     0.04910     0.00852   0.00510
# ..      ...      ...            ...         ...         ...       ...
# 484       3  6.62772        0.01023     0.85037     1.45853   0.00842
# 485       3  6.69408        0.02856     0.85920     1.13082   0.01391
# 486       3  6.76090        0.01646     1.26521     1.13588   0.00054
# 487       3  6.93692        0.00550     0.47417     0.65103   0.03088
# 488       3  7.03690        0.02259     1.22610     0.76160   0.02266
#
#      ratio_legR  ratio_legL
# 0       1.23466     1.09339
# 1       1.20358     1.14582
# 2       1.18914     1.12053
# ...

# %%
df.dropna()
# Out:
#      tester      time  diff_shoulder  ratio_armR  ratio_armL  diff_hip  \
# 1         1 -4.999956       0.006349    0.176537    0.223549  0.006989
# 2         1 -4.931930       0.005293    0.059412    0.106444  0.006060
# 3         1 -4.866806       0.004290    0.011301    0.045611  0.005444
# 4         1 -4.800642       0.003731    0.049095    0.008524  0.005096
# 5         1 -4.732744       0.002995    0.047744    0.008877  0.004904
# ..      ...       ...            ...         ...         ...       ...
# 484       3  6.627717       0.010227    0.850367    1.458529  0.008415
# 485       3  6.694076       0.028560    0.859202    1.130818  0.013907
# 486       3  6.760897       0.016456    1.265210    1.135882  0.000540
# 487       3  6.936917       0.005498    0.474172    0.651029  0.030880
# 488       3  7.036903       0.022592    1.226096    0.761601  0.022664
#
#      ratio_legR  ratio_legL
# 1      1.203576    1.145825
# 2      1.189136    1.120530
# ...

# %%
df = df[df['time'] >= 0] #cut out the preparing time

# %%
df
# Out:
#      tester      time  diff_shoulder  ratio_armR  ratio_armL  diff_hip  \
# 70        1  0.030470       0.035947    1.172538    1.282543  0.003595
# 71        1  0.097784       0.048662    1.130393    1.198369  0.005226
# 72        1  0.164511       0.043374    1.049371    1.218165  0.004863
# 73        1  0.230586       0.030575    1.068455    1.183540  0.005795
# 74        1  0.298068       0.024009    1.057174    1.187752  0.000463
# ..      ...       ...            ...         ...         ...       ...
# 484       3  6.627717       0.010227    0.850367    1.458529  0.008415
# 485       3  6.694076       0.028560    0.859202    1.130818  0.013907
# 486       3  6.760897       0.016456    1.265210    1.135882  0.000540
# 487       3  6.936917       0.005498    0.474172    0.651029  0.030880
# 488       3  7.036903       0.022592    1.226096    0.761601  0.022664
#
#      ratio_legR  ratio_legL
# 70     0.994311    1.037404
# 71     0.990683    1.034908
# ...

# %% [markdown]
# data preparation

# %%
df1 = df[df['tester'] == 1]
df1.sort_values('time')
# Out:
#      tester      time  diff_shoulder  ratio_armR  ratio_armL  diff_hip  \
# 70        1  0.030470       0.035947    1.172538    1.282543  0.003595
# 71        1  0.097784       0.048662    1.130393    1.198369  0.005226
# 72        1  0.164511       0.043374    1.049371    1.218165  0.004863
# 73        1  0.230586       0.030575    1.068455    1.183540  0.005795
# 74        1  0.298068       0.024009    1.057174    1.187752  0.000463
# 75        1  0.364031       0.021775    1.019317    1.173900  0.000079
# 76        1  0.431211       0.022666    1.024533    1.213072  0.001859
# 77        1  0.497296       0.029601    1.093037    1.184667  0.001812
# 78        1  0.564445       0.028718    1.196189    1.247558  0.001673
# 79        1  0.630507       0.025258    1.201081    1.210494  0.001904
# 80        1  0.697677       0.025284    1.208279    1.176762  0.002066
# 81        1  0.764405       0.027405    1.183179    1.149266  0.004110
# ...

# %%
df2 = df[df['tester'] == 2]
df2.sort_values('time')
# Out:
#      tester      time  diff_shoulder  ratio_armR  ratio_armL  diff_hip  \
# 181       2  0.000486       0.022513    1.032865    1.185330  0.005497
# 182       2  0.064139       0.021663    1.035792    1.185705  0.008059
# 183       2  0.131420       0.028192    1.025924    1.148287  0.007162
# 184       2  0.198258       0.031417    1.035876    1.053721  0.001763
# 185       2  0.266081       0.037605    0.970191    1.093894  0.002425
# ..      ...       ...            ...         ...         ...       ...
# 311       2  8.659615       0.013763    0.852715    1.271138  0.002196
# 312       2  8.728618       0.019356    0.813741    1.334340  0.004988
# 313       2  8.793308       0.019630    0.800127    1.380660  0.002542
# 314       2  8.859501       0.040318    0.769234    1.470869  0.009681
# 315       2  8.926656       0.043967    0.708665    1.467471  0.003332
#
#      ratio_legR  ratio_legL
# 181    1.048422    0.958601
# 182    1.039572    0.984466
# ...

# %%
df3 = df[df['tester'] == 3]
df3.sort_values('time')
# Out:
#      tester      time  diff_shoulder  ratio_armR  ratio_armL  diff_hip  \
# 393       3  0.032382       0.000278    1.281532    1.469218  0.010993
# 394       3  0.100961       0.000194    1.281368    1.475474  0.010204
# 395       3  0.163591       0.000521    1.287037    1.488795  0.010353
# 396       3  0.233518       0.000462    1.297283    1.531188  0.010209
# 397       3  0.298214       0.001469    1.296301    1.562616  0.010228
# ..      ...       ...            ...         ...         ...       ...
# 484       3  6.627717       0.010227    0.850367    1.458529  0.008415
# 485       3  6.694076       0.028560    0.859202    1.130818  0.013907
# 486       3  6.760897       0.016456    1.265210    1.135882  0.000540
# 487       3  6.936917       0.005498    0.474172    0.651029  0.030880
# 488       3  7.036903       0.022592    1.226096    0.761601  0.022664
#
#      ratio_legR  ratio_legL
# 393    0.832399    1.024305
# 394    0.829457    1.040021
# ...

# %% [markdown]
# diff_shoulder

# %%
diff_shoulder1 = df1[['diff_shoulder']]
diff_shoulder1
# Out:
#      diff_shoulder
# 70        0.035947
# 71        0.048662
# 72        0.043374
# 73        0.030575
# 74        0.024009
# 75        0.021775
# 76        0.022666
# 77        0.029601
# 78        0.028718
# 79        0.025258
# 80        0.025284
# 81        0.027405
# 82        0.032949
# 83        0.042397
# 84        0.054247
# 85        0.053587
# 86        0.054574
# 87        0.052749
# 88        0.048627
# 89        0.037477
# 90        0.025990
# 91        0.008153
# 92        0.002425
# 93        0.005097
# 94        0.010213
# 95        0.016957
# 96        0.022283
# 97        0.032192
# 98        0.013172
# 99        0.009929
# 100       0.007501
# 101       0.010224
# 102       0.072019
# 103       0.019929
# 104       0.018974

# %%
x1 = diff_shoulder1.to_numpy()
x1
# Out:
# array([[0.03594664],
#        [0.04866214],
#        [0.04337411],
#        [0.03057465],
#        [0.02400911],
#        [0.02177486],
#        [0.02266619],
#        [0.02960072],
#        [0.0287182 ],
#        [0.0252583 ],
#        [0.02528442],
#        [0.02740468],
#        [0.032949  ],
#        [0.04239704],
#        [0.05424678],
#        [0.05358687],
#        [0.0545737 ],
#        [0.05274871],
#        [0.04862736],
#        [0.0374774 ],
#        [0.02598961],
#        [0.00815342],
#        [0.00242488],
#        [0.00509681],
#        [0.01021324],
#        [0.01695693],
#        [0.02228295],
#        [0.03219212],
#        [0.0131722 ],
#        [0.00992923],
#        [0.00750069],
#        [0.01022398],
#        [0.07201914],
#        [0.01992887],
#        [0.01897362]])

# %%
diff_shoulder2 = df2[['diff_shoulder']]
diff_shoulder2
x2 = diff_shoulder2.to_numpy()
x2
# Out:
# array([[0.0225127 ],
#        [0.02166349],
#        [0.02819175],
#        [0.0314168 ],
#        [0.03760454],
#        [0.04498088],
#        [0.0480938 ],
#        [0.05228448],
#        [0.05057006],
#        [0.04589324],
#        [0.04046533],
#        [0.02715339],
#        [0.01714654],
#        [0.0110341 ],
#        [0.00595012],
#        [0.00204872],
#        [0.00070678],
#        [0.00472444],
#        [0.00476202],
#        [0.00100482],
#        [0.00246197],
#        [0.00174183],
#        [0.00221629],
#        [0.00048281],
#        [0.00208621],
#        [0.00181974],
#        [0.00327656],
#        [0.0028366 ],
#        [0.00319026],
#        [0.00614797],
#        [0.01175031],
#        [0.01188157],
#        [0.01845057],
#        [0.02376221],
#        [0.0232102 ],
#        [0.02209064],
#        [0.02155529],
#        [0.02245949],
#        [0.02261947],
#        [0.02287841],
#        [0.03114517],
#        [0.03997411],
#        [0.04618725],
# ...

# %%
diff_shoulder3 = df3[['diff_shoulder']]
diff_shoulder3
x3 = diff_shoulder3.to_numpy()
x3
# Out:
# array([[0.00027752],
#        [0.00019354],
#        [0.00052136],
#        [0.00046197],
#        [0.00146881],
#        [0.0014171 ],
#        [0.00150946],
#        [0.00174052],
#        [0.0033946 ],
#        [0.00625807],
#        [0.0068011 ],
#        [0.00989723],
#        [0.01000264],
#        [0.00785521],
#        [0.00010109],
#        [0.01404917],
#        [0.01460204],
#        [0.01476255],
#        [0.00996809],
#        [0.00877817],
#        [0.00719391],
#        [0.00053398],
#        [0.00026357],
#        [0.00408359],
#        [0.00837681],
#        [0.01352978],
#        [0.01607212],
#        [0.01647928],
#        [0.01735981],
#        [0.01757848],
#        [0.01881574],
#        [0.01582673],
#        [0.01572755],
#        [0.01297466],
#        [0.01075044],
#        [0.00462382],
#        [0.00198668],
#        [0.00042655],
#        [0.00593974],
#        [0.01179409],
#        [0.016966  ],
#        [0.01799597],
#        [0.01461212],
# ...

# %%
X = [x1,x2,x3]
X.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[305], line 2
#       1 X = ['x1','x2','x3']
# ----> 2 X.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
y = [[0,1,1]]
y.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[306], line 2
#       1 y = [[0,1,1]]
# ----> 2 y.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[307], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
#       2 from sklearn.linear_model import LogisticRegression
#       3 from sklearn import metrics
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/model_selection/_split.py:2559, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2556 if n_arrays == 0:
#    2557     raise ValueError("At least one array required as input")
# -> 2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
#    2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#
# ...
